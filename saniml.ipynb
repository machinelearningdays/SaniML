# %% [markdown]
# ## Çalışmamızı google colab üzerinde yapacağımız için drive'a erişim istiyoruz.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Tüm veriyi işlenmeden önce 256*256 boyutunda yeniden şekillendiriyoruz.

# %%
import PIL
import os
from PIL import Image

f = '/content/drive/My Drive/mama-kabı/test/dolu'
for file in os.listdir(f):
    f_img = f+"/"+file
    img = Image.open(f_img)
    img = img.resize((256,256))
    img.save(f_img)

# %%
import PIL
import os
from PIL import Image

f = '/content/drive/My Drive/mama-kabı/test/boş'
for file in os.listdir(f):
    f_img = f+"/"+file
    img = Image.open(f_img)
    img = img.resize((256,256))
    img.save(f_img)

# %%
import PIL
import os
from PIL import Image

f = '/content/drive/My Drive/mama-kabı/train/dolu'
for file in os.listdir(f):
    f_img = f+"/"+file
    img = Image.open(f_img)
    img = img.resize((256,256))
    img.save(f_img)

# %%
import PIL
import os
from PIL import Image

f = '/content/drive/My Drive/mama-kabı/train/boş'
for file in os.listdir(f):
    f_img = f+"/"+file
    img = Image.open(f_img)
    img = img.resize((256,256))
    img.save(f_img)

# %%
import PIL
import os
from PIL import Image

f = '/content/drive/My Drive/mama-kabı/validation/dolu'
for file in os.listdir(f):
    f_img = f+"/"+file
    img = Image.open(f_img)
    img = img.resize((256,256))
    img.save(f_img)

# %%
import PIL
import os
from PIL import Image

f = '/content/drive/My Drive/mama-kabı/validation/boş'
for file in os.listdir(f):
    f_img = f+"/"+file
    img = Image.open(f_img)
    img = img.resize((256,256))
    img.save(f_img)

# %% [markdown]
# ## Gerekli kütüphaneleri yüklüyoruz.

# %%
import os
from keras import layers
from keras import models
import collections
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense 
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K 
import numpy as np
import math
from math import pi
import matplotlib.pyplot as plt
# %matplotlib inline
from random import seed
from random import randint
import glob
import gc
import pandas as pd
seed(1)

# %% [markdown]
# # Modelin eğitimi ve validasyonu sağlayabilmesi için erişmesi gereken dosyaların yolunu bir değişkene aktarıyoruz.
# ## Sonrasında veri formatını kontrol ediyoruz.

# %%
img_width, img_height = 256, 256
train_data_dir = '/content/drive/My Drive/mama-kabı/train'

validation_data_dir = '/content/drive/My Drive/mama-kabı/validation'

epochs = 100
batch_size = 4
if K.image_data_format() == 'channels_first': 
    input_shape = (3, img_width, img_height) 
else: 
    input_shape = (img_width, img_height, 3)

# %% [markdown]
# ## Keras tabanlı ikili sınıflandırma yapacağımız modeli yüklüyoruz.

# %%
model = Sequential() 
model.add(Conv2D(32, (2, 2), input_shape=input_shape)) #görüntüyü birden çok görüntüye dönüştüren katman"""
model.add(Activation('relu')) #etkinleştirme işlevi"""
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Conv2D(32, (2, 2))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Conv2D(64, (2, 2))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Flatten()) #convlving sonrası katman"""
model.add(Dense(64)) #fully-connected katmanı"""
model.add(Activation('relu')) 
model.add(Dropout(0.5)) #overfitting olmasını engellemek için kullanılır"""
model.add(Dense(1)) #çıktı katmanındaki görüntünün hangi kategoriye ait olduğuna karar veren yalnızca bir nöron içerir."""
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', 
              optimizer='rmsprop', 
              metrics=['accuracy'],
              run_eagerly=True)

# %% [markdown]
# ## DataGenarator kullanımı ve training

# %%
train_datagen = ImageDataGenerator( 
    rescale=1. / 255, 
    shear_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True) 
  
test_datagen = ImageDataGenerator(rescale=1. / 255) 

import glob
leng=len(glob.glob(train_data_dir +'/*/*.JPG'))
lengval=len(glob.glob(validation_data_dir+'/*/*.JPG'))
  
train_generator = train_datagen.flow_from_directory( 
    train_data_dir, 
    target_size=(img_width, img_height), 
    batch_size=batch_size, 
    class_mode='binary') 
  
validation_generator = test_datagen.flow_from_directory( 
    validation_data_dir, 
    target_size=(img_width, img_height), 
    batch_size=batch_size, 
    class_mode='binary') 
 
hist=model.fit_generator( 
    train_generator, 
    steps_per_epoch=leng // batch_size, 
    epochs=300, 
    validation_data=validation_generator, 
    validation_steps=lengval // batch_size,
    )
# Out:
# Found 192 images belonging to 2 classes.
# Found 96 images belonging to 2 classes.
# Epoch 1/300
# 6/6 [==============================] - 3s 522ms/step - loss: 1.2593 - accuracy: 0.4583 - val_loss: 0.6737 - val_accuracy: 0.5789
# Epoch 2/300
# 6/6 [==============================] - 3s 489ms/step - loss: 0.7291 - accuracy: 0.5417 - val_loss: 0.6393 - val_accuracy: 0.7368
# Epoch 3/300
# 6/6 [==============================] - 3s 487ms/step - loss: 0.7028 - accuracy: 0.5833 - val_loss: 0.6189 - val_accuracy: 0.6447
# Epoch 4/300
# 6/6 [==============================] - 3s 487ms/step - loss: 0.6723 - accuracy: 0.6667 - val_loss: 0.6534 - val_accuracy: 0.5921
# Epoch 5/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.5805 - accuracy: 0.7917 - val_loss: 0.5523 - val_accuracy: 0.8553
# Epoch 6/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.5343 - accuracy: 0.7917 - val_loss: 0.5910 - val_accuracy: 0.6447
# Epoch 7/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.9875 - accuracy: 0.6667 - val_loss: 0.5739 - val_accuracy: 0.8553
# Epoch 8/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.6802 - accuracy: 0.6250 - val_loss: 0.5505 - val_accuracy: 0.7763
# Epoch 9/300
# 6/6 [==============================] - 3s 507ms/step - loss: 0.6105 - accuracy: 0.6667 - val_loss: 0.5664 - val_accuracy: 0.7105
# Epoch 10/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.5922 - accuracy: 0.5417 - val_loss: 0.6145 - val_accuracy: 0.7895
# Epoch 11/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.6374 - accuracy: 0.7083 - val_loss: 0.4769 - val_accuracy: 0.8684
# Epoch 12/300
# 6/6 [==============================] - 3s 489ms/step - loss: 0.7540 - accuracy: 0.6250 - val_loss: 0.4634 - val_accuracy: 0.8816
# Epoch 13/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.8779 - accuracy: 0.5833 - val_loss: 0.4977 - val_accuracy: 0.8289
# Epoch 14/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.4799 - accuracy: 0.7917 - val_loss: 0.4394 - val_accuracy: 0.8289
# Epoch 15/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.5500 - accuracy: 0.5833 - val_loss: 0.3886 - val_accuracy: 0.9079
# Epoch 16/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.5759 - accuracy: 0.7500 - val_loss: 0.3510 - val_accuracy: 0.8684
# Epoch 17/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.5530 - accuracy: 0.7083 - val_loss: 0.3007 - val_accuracy: 0.8947
# Epoch 18/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.4427 - accuracy: 0.8750 - val_loss: 0.2849 - val_accuracy: 0.9342
# Epoch 19/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.4297 - accuracy: 0.7917 - val_loss: 0.3527 - val_accuracy: 0.9079
# Epoch 20/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.3451 - accuracy: 0.8333 - val_loss: 0.3803 - val_accuracy: 0.7895
# Epoch 21/300
# 6/6 [==============================] - 3s 486ms/step - loss: 0.2868 - accuracy: 0.8750 - val_loss: 0.4099 - val_accuracy: 0.8684
# Epoch 22/300
# 6/6 [==============================] - 3s 486ms/step - loss: 0.9181 - accuracy: 0.7500 - val_loss: 0.2389 - val_accuracy: 0.9079
# Epoch 23/300
# 6/6 [==============================] - 3s 501ms/step - loss: 0.5362 - accuracy: 0.7917 - val_loss: 0.2365 - val_accuracy: 0.9211
# Epoch 24/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.5164 - accuracy: 0.7500 - val_loss: 0.2674 - val_accuracy: 0.9737
# Epoch 25/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.2656 - accuracy: 0.9583 - val_loss: 0.2664 - val_accuracy: 0.8421
# Epoch 26/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.3504 - accuracy: 0.8333 - val_loss: 0.9309 - val_accuracy: 0.6316
# Epoch 27/300
# 6/6 [==============================] - 3s 503ms/step - loss: 0.4816 - accuracy: 0.8333 - val_loss: 0.1631 - val_accuracy: 0.9474
# Epoch 28/300
# 6/6 [==============================] - 3s 503ms/step - loss: 0.1793 - accuracy: 0.9583 - val_loss: 0.1393 - val_accuracy: 0.9342
# Epoch 29/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.4421 - accuracy: 0.9167 - val_loss: 0.1552 - val_accuracy: 0.9342
# Epoch 30/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.2778 - accuracy: 0.8750 - val_loss: 0.1727 - val_accuracy: 0.9211
# Epoch 31/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.2588 - accuracy: 0.9167 - val_loss: 0.2673 - val_accuracy: 0.9079
# Epoch 32/300
# 6/6 [==============================] - 3s 485ms/step - loss: 0.2779 - accuracy: 0.8750 - val_loss: 0.2504 - val_accuracy: 0.8947
# Epoch 33/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.2352 - accuracy: 0.8750 - val_loss: 0.2859 - val_accuracy: 0.9211
# Epoch 34/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.3671 - accuracy: 0.8750 - val_loss: 0.1969 - val_accuracy: 0.9211
# Epoch 35/300
# 6/6 [==============================] - 3s 508ms/step - loss: 0.2463 - accuracy: 0.8750 - val_loss: 0.0863 - val_accuracy: 0.9868
# Epoch 36/300
# 6/6 [==============================] - 3s 510ms/step - loss: 0.4419 - accuracy: 0.8333 - val_loss: 0.1011 - val_accuracy: 0.9737
# Epoch 37/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.1215 - accuracy: 0.9583 - val_loss: 0.3035 - val_accuracy: 0.8816
# Epoch 38/300
# 6/6 [==============================] - 3s 501ms/step - loss: 0.2496 - accuracy: 0.9167 - val_loss: 0.4692 - val_accuracy: 0.8553
# Epoch 39/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.1432 - accuracy: 0.9583 - val_loss: 0.0901 - val_accuracy: 0.9737
# Epoch 40/300
# 6/6 [==============================] - 3s 486ms/step - loss: 0.1936 - accuracy: 0.8750 - val_loss: 0.2214 - val_accuracy: 0.9342
# Epoch 41/300
# 6/6 [==============================] - 3s 488ms/step - loss: 0.2449 - accuracy: 0.8750 - val_loss: 0.2014 - val_accuracy: 0.9474
# Epoch 42/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.2845 - accuracy: 0.8750 - val_loss: 0.3933 - val_accuracy: 0.9211
# Epoch 43/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.1725 - accuracy: 0.9583 - val_loss: 0.1728 - val_accuracy: 0.9342
# Epoch 44/300
# 6/6 [==============================] - 3s 487ms/step - loss: 0.2521 - accuracy: 0.9167 - val_loss: 0.2817 - val_accuracy: 0.8947
# Epoch 45/300
# 6/6 [==============================] - 3s 527ms/step - loss: 0.0894 - accuracy: 1.0000 - val_loss: 0.2402 - val_accuracy: 0.9079
# Epoch 46/300
# 6/6 [==============================] - 3s 509ms/step - loss: 0.2752 - accuracy: 0.8750 - val_loss: 0.3363 - val_accuracy: 0.9079
# Epoch 47/300
# 6/6 [==============================] - 3s 513ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9474
# Epoch 48/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0808 - accuracy: 0.9583 - val_loss: 0.2452 - val_accuracy: 0.9342
# Epoch 49/300
# 6/6 [==============================] - 3s 501ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9342
# Epoch 50/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.2953 - accuracy: 0.8750 - val_loss: 0.1149 - val_accuracy: 0.9474
# Epoch 51/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.4092 - accuracy: 0.9167 - val_loss: 0.0673 - val_accuracy: 0.9737
# Epoch 52/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9342
# Epoch 53/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.2640 - accuracy: 0.9167 - val_loss: 0.4951 - val_accuracy: 0.8553
# Epoch 54/300
# 6/6 [==============================] - 3s 511ms/step - loss: 0.1650 - accuracy: 0.9167 - val_loss: 0.1541 - val_accuracy: 0.9342
# Epoch 55/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.1676 - accuracy: 0.9167 - val_loss: 0.0844 - val_accuracy: 0.9605
# Epoch 56/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0889 - accuracy: 0.9167 - val_loss: 0.6771 - val_accuracy: 0.8421
# Epoch 57/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.1931 - accuracy: 0.9167 - val_loss: 0.7774 - val_accuracy: 0.8553
# Epoch 58/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9211
# Epoch 59/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.5685 - accuracy: 0.7500 - val_loss: 0.2483 - val_accuracy: 0.9342
# Epoch 60/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.1141 - accuracy: 0.9583 - val_loss: 0.1866 - val_accuracy: 0.9474
# Epoch 61/300
# 6/6 [==============================] - 3s 503ms/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.2158 - val_accuracy: 0.9342
# Epoch 62/300
# 6/6 [==============================] - 3s 509ms/step - loss: 0.0648 - accuracy: 0.9583 - val_loss: 0.1460 - val_accuracy: 0.9605
# Epoch 63/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.2431 - accuracy: 0.8750 - val_loss: 0.0736 - val_accuracy: 0.9868
# Epoch 64/300
# 6/6 [==============================] - 3s 514ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9605
# Epoch 65/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.1030 - accuracy: 0.9583 - val_loss: 0.1544 - val_accuracy: 0.9342
# Epoch 66/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.1091 - val_accuracy: 0.9342
# Epoch 67/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.9474
# Epoch 68/300
# 6/6 [==============================] - 3s 519ms/step - loss: 0.9805 - accuracy: 0.9167 - val_loss: 0.5712 - val_accuracy: 0.9211
# Epoch 69/300
# 6/6 [==============================] - 3s 561ms/step - loss: 0.6986 - accuracy: 0.9583 - val_loss: 0.2742 - val_accuracy: 0.9211
# Epoch 70/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0493 - accuracy: 0.9583 - val_loss: 0.1009 - val_accuracy: 0.9474
# Epoch 71/300
# 6/6 [==============================] - 3s 510ms/step - loss: 0.3543 - accuracy: 0.8333 - val_loss: 0.8505 - val_accuracy: 0.8553
# Epoch 72/300
# 6/6 [==============================] - 3s 517ms/step - loss: 0.4408 - accuracy: 0.9167 - val_loss: 0.1056 - val_accuracy: 0.9605
# Epoch 73/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.1234 - accuracy: 0.9583 - val_loss: 0.1092 - val_accuracy: 0.9737
# Epoch 74/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9605
# Epoch 75/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.0831 - accuracy: 0.9583 - val_loss: 0.0922 - val_accuracy: 0.9868
# Epoch 76/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.1383 - accuracy: 0.9583 - val_loss: 0.0928 - val_accuracy: 0.9868
# Epoch 77/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.6043 - accuracy: 0.9167 - val_loss: 0.1954 - val_accuracy: 0.9474
# Epoch 78/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9342
# Epoch 79/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0972 - accuracy: 0.9583 - val_loss: 0.4801 - val_accuracy: 0.9211
# Epoch 80/300
# 6/6 [==============================] - 3s 501ms/step - loss: 0.3507 - accuracy: 0.8750 - val_loss: 0.1946 - val_accuracy: 0.9605
# Epoch 81/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9342
# Epoch 82/300
# 6/6 [==============================] - 3s 488ms/step - loss: 0.0538 - accuracy: 0.9583 - val_loss: 0.2083 - val_accuracy: 0.9211
# Epoch 83/300
# 6/6 [==============================] - 3s 482ms/step - loss: 0.0553 - accuracy: 0.9583 - val_loss: 0.3362 - val_accuracy: 0.9342
# Epoch 84/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.7425 - accuracy: 0.7500 - val_loss: 0.2815 - val_accuracy: 0.9605
# Epoch 85/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.1010 - accuracy: 0.9583 - val_loss: 0.3130 - val_accuracy: 0.9474
# Epoch 86/300
# 6/6 [==============================] - 3s 487ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4060 - val_accuracy: 0.9342
# Epoch 87/300
# 6/6 [==============================] - 3s 492ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4299 - val_accuracy: 0.9474
# Epoch 88/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9605
# Epoch 89/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.3277 - accuracy: 0.9167 - val_loss: 0.0891 - val_accuracy: 0.9474
# Epoch 90/300
# 6/6 [==============================] - 3s 494ms/step - loss: 0.2264 - accuracy: 0.9583 - val_loss: 0.3449 - val_accuracy: 0.9474
# Epoch 91/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.1671 - accuracy: 0.9167 - val_loss: 0.5339 - val_accuracy: 0.8684
# Epoch 92/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.1078 - accuracy: 0.9167 - val_loss: 0.5108 - val_accuracy: 0.9079
# Epoch 93/300
# 6/6 [==============================] - 3s 488ms/step - loss: 0.1653 - accuracy: 0.9583 - val_loss: 0.0910 - val_accuracy: 0.9474
# Epoch 94/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0474 - accuracy: 0.9583 - val_loss: 0.2789 - val_accuracy: 0.9474
# Epoch 95/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.3340 - accuracy: 0.9167 - val_loss: 0.2391 - val_accuracy: 0.9211
# Epoch 96/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9737
# Epoch 97/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2356 - val_accuracy: 0.9605
# Epoch 98/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.1217 - accuracy: 0.9167 - val_loss: 0.2838 - val_accuracy: 0.9342
# Epoch 99/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.2543 - accuracy: 0.9583 - val_loss: 0.1652 - val_accuracy: 0.9342
# Epoch 100/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0718 - accuracy: 0.9583 - val_loss: 0.5732 - val_accuracy: 0.8684
# Epoch 101/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.2340 - accuracy: 0.9167 - val_loss: 0.2767 - val_accuracy: 0.9474
# Epoch 102/300
# 6/6 [==============================] - 3s 486ms/step - loss: 0.0349 - accuracy: 1.0000 - val_loss: 0.2247 - val_accuracy: 0.9605
# Epoch 103/300
# 6/6 [==============================] - 3s 501ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9342
# Epoch 104/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.2908 - accuracy: 0.8750 - val_loss: 0.4190 - val_accuracy: 0.9079
# Epoch 105/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9605
# Epoch 106/300
# 6/6 [==============================] - 3s 507ms/step - loss: 0.2072 - accuracy: 0.8750 - val_loss: 0.2343 - val_accuracy: 0.9605
# Epoch 107/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9605
# Epoch 108/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.0472 - accuracy: 0.9583 - val_loss: 0.4031 - val_accuracy: 0.9211
# Epoch 109/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.1756 - accuracy: 0.9583 - val_loss: 0.5208 - val_accuracy: 0.9342
# Epoch 110/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.1072 - accuracy: 0.9583 - val_loss: 0.4247 - val_accuracy: 0.9342
# Epoch 111/300
# 6/6 [==============================] - 3s 484ms/step - loss: 0.1040 - accuracy: 0.9583 - val_loss: 0.3310 - val_accuracy: 0.9342
# Epoch 112/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2711 - val_accuracy: 0.9211
# Epoch 113/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.9211
# Epoch 114/300
# 6/6 [==============================] - 3s 501ms/step - loss: 0.0762 - accuracy: 0.9583 - val_loss: 0.2284 - val_accuracy: 0.9211
# Epoch 115/300
# 6/6 [==============================] - 3s 506ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9737
# Epoch 116/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9605
# Epoch 117/300
# 6/6 [==============================] - 3s 494ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9474
# Epoch 118/300
# 6/6 [==============================] - 3s 492ms/step - loss: 0.5262 - accuracy: 0.9167 - val_loss: 0.1849 - val_accuracy: 0.9605
# Epoch 119/300
# 6/6 [==============================] - 3s 494ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.9342
# Epoch 120/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 1.7705 - val_accuracy: 0.8026
# Epoch 121/300
# 6/6 [==============================] - 3s 501ms/step - loss: 0.3837 - accuracy: 0.8333 - val_loss: 0.3253 - val_accuracy: 0.9474
# Epoch 122/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.0572 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9605
# Epoch 123/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9737
# Epoch 124/300
# 6/6 [==============================] - 3s 509ms/step - loss: 0.0566 - accuracy: 0.9583 - val_loss: 0.2920 - val_accuracy: 0.9474
# Epoch 125/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.2080 - accuracy: 0.9583 - val_loss: 0.3901 - val_accuracy: 0.9211
# Epoch 126/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.3749 - accuracy: 0.8750 - val_loss: 0.1804 - val_accuracy: 0.9737
# Epoch 127/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9868
# Epoch 128/300
# 6/6 [==============================] - 3s 489ms/step - loss: 0.1876 - accuracy: 0.9583 - val_loss: 0.0897 - val_accuracy: 0.9737
# Epoch 129/300
# 6/6 [==============================] - 3s 487ms/step - loss: 0.4432 - accuracy: 0.9167 - val_loss: 0.1217 - val_accuracy: 0.9605
# Epoch 130/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.0592 - accuracy: 0.9583 - val_loss: 0.2401 - val_accuracy: 0.9737
# Epoch 131/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.2182 - val_accuracy: 0.9737
# Epoch 132/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9868
# Epoch 133/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9868
# Epoch 134/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0485 - accuracy: 0.9583 - val_loss: 0.2681 - val_accuracy: 0.9211
# Epoch 135/300
# 6/6 [==============================] - 3s 494ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9737
# Epoch 136/300
# 6/6 [==============================] - 3s 487ms/step - loss: 0.2054 - accuracy: 0.9167 - val_loss: 0.0594 - val_accuracy: 0.9868
# Epoch 137/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.1761 - accuracy: 0.9167 - val_loss: 0.8160 - val_accuracy: 0.8684
# Epoch 138/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0988 - accuracy: 0.9583 - val_loss: 0.3387 - val_accuracy: 0.9474
# Epoch 139/300
# 6/6 [==============================] - 3s 511ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.3047 - val_accuracy: 0.9737
# Epoch 140/300
# 6/6 [==============================] - 3s 507ms/step - loss: 0.0397 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9868
# Epoch 141/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.1925 - val_accuracy: 0.9737
# Epoch 142/300
# 6/6 [==============================] - 3s 506ms/step - loss: 0.0447 - accuracy: 0.9583 - val_loss: 0.3572 - val_accuracy: 0.9474
# Epoch 143/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.5210 - accuracy: 0.9167 - val_loss: 0.1488 - val_accuracy: 0.9737
# Epoch 144/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.9605
# Epoch 145/300
# 6/6 [==============================] - 3s 483ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2482 - val_accuracy: 0.9605
# Epoch 146/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.2973 - accuracy: 0.8750 - val_loss: 0.3100 - val_accuracy: 0.9211
# Epoch 147/300
# 6/6 [==============================] - 3s 492ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.3607 - val_accuracy: 0.9474
# Epoch 148/300
# 6/6 [==============================] - 3s 494ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.1968 - val_accuracy: 0.9737
# Epoch 149/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.3709 - accuracy: 0.9167 - val_loss: 0.1844 - val_accuracy: 0.9474
# Epoch 150/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.1120 - accuracy: 0.9583 - val_loss: 0.2032 - val_accuracy: 0.9474
# Epoch 151/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2414 - val_accuracy: 0.9342
# Epoch 152/300
# 6/6 [==============================] - 3s 501ms/step - loss: 0.1090 - accuracy: 0.9583 - val_loss: 0.1867 - val_accuracy: 0.9737
# Epoch 153/300
# 6/6 [==============================] - 3s 485ms/step - loss: 0.0735 - accuracy: 0.9583 - val_loss: 0.2065 - val_accuracy: 0.9737
# Epoch 154/300
# 6/6 [==============================] - 3s 485ms/step - loss: 0.0496 - accuracy: 0.9583 - val_loss: 0.3017 - val_accuracy: 0.9342
# Epoch 155/300
# 6/6 [==============================] - 3s 489ms/step - loss: 0.0821 - accuracy: 0.9583 - val_loss: 0.3431 - val_accuracy: 0.9474
# Epoch 156/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9605
# Epoch 157/300
# 6/6 [==============================] - 3s 494ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3185 - val_accuracy: 0.9474
# Epoch 158/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.3978 - val_accuracy: 0.9737
# Epoch 159/300
# 6/6 [==============================] - 3s 539ms/step - loss: 0.2981 - accuracy: 0.9583 - val_loss: 0.1357 - val_accuracy: 0.9737
# Epoch 160/300
# 6/6 [==============================] - 3s 537ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4978 - val_accuracy: 0.9342
# Epoch 161/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.9342
# Epoch 162/300
# 6/6 [==============================] - 3s 487ms/step - loss: 5.7537e-06 - accuracy: 1.0000 - val_loss: 0.3406 - val_accuracy: 0.9474
# Epoch 163/300
# 6/6 [==============================] - 3s 485ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2953 - val_accuracy: 0.9474
# Epoch 164/300
# 6/6 [==============================] - 3s 490ms/step - loss: 3.9942e-04 - accuracy: 1.0000 - val_loss: 0.1923 - val_accuracy: 0.9605
# Epoch 165/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.0451 - accuracy: 0.9583 - val_loss: 0.5273 - val_accuracy: 0.9342
# Epoch 166/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.0493 - accuracy: 0.9583 - val_loss: 0.3592 - val_accuracy: 0.9342
# Epoch 167/300
# 6/6 [==============================] - 3s 505ms/step - loss: 2.1253e-05 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.9474
# Epoch 168/300
# 6/6 [==============================] - 3s 496ms/step - loss: 5.5762e-04 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9737
# Epoch 169/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1862 - val_accuracy: 0.9474
# Epoch 170/300
# 6/6 [==============================] - 3s 496ms/step - loss: 2.1579e-05 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9605
# Epoch 171/300
# 6/6 [==============================] - 3s 487ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4296 - val_accuracy: 0.9342
# Epoch 172/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.1776 - accuracy: 0.9167 - val_loss: 0.2864 - val_accuracy: 0.9342
# Epoch 173/300
# 6/6 [==============================] - 3s 485ms/step - loss: 5.7746e-04 - accuracy: 1.0000 - val_loss: 0.1640 - val_accuracy: 0.9605
# Epoch 174/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.2761 - accuracy: 0.9583 - val_loss: 0.1695 - val_accuracy: 0.9737
# Epoch 175/300
# 6/6 [==============================] - 3s 494ms/step - loss: 1.1596 - accuracy: 0.8333 - val_loss: 0.1613 - val_accuracy: 0.9605
# Epoch 176/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.1991 - accuracy: 0.9583 - val_loss: 0.1966 - val_accuracy: 0.9737
# Epoch 177/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.9737
# Epoch 178/300
# 6/6 [==============================] - 3s 508ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9868
# Epoch 179/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9868
# Epoch 180/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9737
# Epoch 181/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9868
# Epoch 182/300
# 6/6 [==============================] - 3s 484ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2181 - val_accuracy: 0.9737
# Epoch 183/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.8061 - accuracy: 0.8750 - val_loss: 0.2811 - val_accuracy: 0.9342
# Epoch 184/300
# 6/6 [==============================] - 3s 493ms/step - loss: 4.0170e-04 - accuracy: 1.0000 - val_loss: 0.2423 - val_accuracy: 0.9474
# Epoch 185/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.1314 - accuracy: 0.9167 - val_loss: 0.1901 - val_accuracy: 0.9737
# Epoch 186/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2556 - val_accuracy: 0.9605
# Epoch 187/300
# 6/6 [==============================] - 3s 494ms/step - loss: 3.4381e-04 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9605
# Epoch 188/300
# 6/6 [==============================] - 3s 486ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2755 - val_accuracy: 0.9605
# Epoch 189/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.0834 - accuracy: 0.9583 - val_loss: 0.2023 - val_accuracy: 0.9868
# Epoch 190/300
# 6/6 [==============================] - 3s 482ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9605
# Epoch 191/300
# 6/6 [==============================] - 3s 486ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3470 - val_accuracy: 0.9737
# Epoch 192/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9868
# Epoch 193/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.2740 - accuracy: 0.9583 - val_loss: 1.4757 - val_accuracy: 0.8289
# Epoch 194/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.2205 - accuracy: 0.9583 - val_loss: 0.1975 - val_accuracy: 0.9868
# Epoch 195/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.3618 - val_accuracy: 0.9737
# Epoch 196/300
# 6/6 [==============================] - 3s 494ms/step - loss: 6.5657e-04 - accuracy: 1.0000 - val_loss: 0.3558 - val_accuracy: 0.9737
# Epoch 197/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9868
# Epoch 198/300
# 6/6 [==============================] - 3s 487ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 1.0351 - val_accuracy: 0.8947
# Epoch 199/300
# 6/6 [==============================] - 3s 484ms/step - loss: 0.4438 - accuracy: 0.9167 - val_loss: 0.4769 - val_accuracy: 0.9211
# Epoch 200/300
# 6/6 [==============================] - 3s 478ms/step - loss: 5.3714e-04 - accuracy: 1.0000 - val_loss: 0.3467 - val_accuracy: 0.9342
# Epoch 201/300
# 6/6 [==============================] - 3s 491ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.6160 - val_accuracy: 0.8947
# Epoch 202/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.0619 - accuracy: 0.9583 - val_loss: 0.1095 - val_accuracy: 0.9868
# Epoch 203/300
# 6/6 [==============================] - 3s 503ms/step - loss: 0.1477 - accuracy: 0.8750 - val_loss: 0.3625 - val_accuracy: 0.9474
# Epoch 204/300
# 6/6 [==============================] - 3s 516ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9605
# Epoch 205/300
# 6/6 [==============================] - 3s 507ms/step - loss: 1.1748e-04 - accuracy: 1.0000 - val_loss: 0.3972 - val_accuracy: 0.9211
# Epoch 206/300
# 6/6 [==============================] - 3s 493ms/step - loss: 0.5728 - accuracy: 0.9167 - val_loss: 1.0116 - val_accuracy: 0.9079
# Epoch 207/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.5080 - accuracy: 0.9167 - val_loss: 0.4673 - val_accuracy: 0.9474
# Epoch 208/300
# 6/6 [==============================] - 3s 489ms/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.2525 - val_accuracy: 0.9605
# Epoch 209/300
# 6/6 [==============================] - 3s 488ms/step - loss: 0.2159 - accuracy: 0.8333 - val_loss: 0.2999 - val_accuracy: 0.9474
# Epoch 210/300
# 6/6 [==============================] - 3s 506ms/step - loss: 0.1920 - accuracy: 0.9583 - val_loss: 0.2577 - val_accuracy: 0.9605
# Epoch 211/300
# 6/6 [==============================] - 3s 494ms/step - loss: 4.4529e-05 - accuracy: 1.0000 - val_loss: 0.2961 - val_accuracy: 0.9474
# Epoch 212/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2530 - val_accuracy: 0.9342
# Epoch 213/300
# 6/6 [==============================] - 3s 508ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.9474
# Epoch 214/300
# 6/6 [==============================] - 3s 500ms/step - loss: 1.5055e-04 - accuracy: 1.0000 - val_loss: 0.2420 - val_accuracy: 0.9605
# Epoch 215/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.1267 - accuracy: 0.9167 - val_loss: 0.3890 - val_accuracy: 0.9605
# Epoch 216/300
# 6/6 [==============================] - 3s 493ms/step - loss: 5.7321e-04 - accuracy: 1.0000 - val_loss: 0.3922 - val_accuracy: 0.9605
# Epoch 217/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3934 - val_accuracy: 0.9474
# Epoch 218/300
# 6/6 [==============================] - 3s 488ms/step - loss: 1.3310e-04 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9737
# Epoch 219/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4162 - val_accuracy: 0.9605
# Epoch 220/300
# 6/6 [==============================] - 3s 505ms/step - loss: 1.7595e-04 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9868
# Epoch 221/300
# 6/6 [==============================] - 3s 503ms/step - loss: 0.1336 - accuracy: 0.9583 - val_loss: 0.2381 - val_accuracy: 0.9342
# Epoch 222/300
# 6/6 [==============================] - 3s 508ms/step - loss: 0.3455 - accuracy: 0.9167 - val_loss: 0.3742 - val_accuracy: 0.9211
# Epoch 223/300
# 6/6 [==============================] - 3s 517ms/step - loss: 0.2062 - accuracy: 0.9583 - val_loss: 0.1884 - val_accuracy: 0.9737
# Epoch 224/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.3276 - val_accuracy: 0.9474
# Epoch 225/300
# 6/6 [==============================] - 3s 517ms/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9737
# Epoch 226/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.3988 - val_accuracy: 0.9737
# Epoch 227/300
# 6/6 [==============================] - 3s 511ms/step - loss: 0.3055 - accuracy: 0.9167 - val_loss: 0.4715 - val_accuracy: 0.9737
# Epoch 228/300
# 6/6 [==============================] - 3s 508ms/step - loss: 0.0455 - accuracy: 0.9583 - val_loss: 0.4295 - val_accuracy: 0.9474
# Epoch 229/300
# 6/6 [==============================] - 3s 542ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.9342
# Epoch 230/300
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.3690 - val_accuracy: 0.9474
# Epoch 231/300
# 6/6 [==============================] - 3s 527ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.9342
# Epoch 232/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.3415 - accuracy: 0.9167 - val_loss: 0.1667 - val_accuracy: 0.9605
# Epoch 233/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.3318 - accuracy: 0.9583 - val_loss: 0.2686 - val_accuracy: 0.9605
# Epoch 234/300
# 6/6 [==============================] - 3s 500ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2861 - val_accuracy: 0.9605
# Epoch 235/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9737
# Epoch 236/300
# 6/6 [==============================] - 3s 500ms/step - loss: 4.6974e-04 - accuracy: 1.0000 - val_loss: 0.2844 - val_accuracy: 0.9605
# Epoch 237/300
# 6/6 [==============================] - 3s 504ms/step - loss: 2.0829e-04 - accuracy: 1.0000 - val_loss: 0.2792 - val_accuracy: 0.9605
# Epoch 238/300
# 6/6 [==============================] - 3s 504ms/step - loss: 6.5792e-04 - accuracy: 1.0000 - val_loss: 0.0989 - val_accuracy: 0.9737
# Epoch 239/300
# 6/6 [==============================] - 3s 516ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2552 - val_accuracy: 0.9605
# Epoch 240/300
# 6/6 [==============================] - 3s 521ms/step - loss: 3.5104e-04 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9605
# Epoch 241/300
# 6/6 [==============================] - 3s 505ms/step - loss: 3.2068e-04 - accuracy: 1.0000 - val_loss: 0.2778 - val_accuracy: 0.9605
# Epoch 242/300
# 6/6 [==============================] - 3s 488ms/step - loss: 5.0441e-04 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9605
# Epoch 243/300
# 6/6 [==============================] - 3s 504ms/step - loss: 6.4719e-04 - accuracy: 1.0000 - val_loss: 0.2609 - val_accuracy: 0.9868
# Epoch 244/300
# 6/6 [==============================] - 3s 502ms/step - loss: 3.0270e-05 - accuracy: 1.0000 - val_loss: 0.2738 - val_accuracy: 0.9737
# Epoch 245/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.2100 - accuracy: 0.9583 - val_loss: 0.9462 - val_accuracy: 0.8816
# Epoch 246/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.3557 - accuracy: 0.9583 - val_loss: 0.1964 - val_accuracy: 0.9474
# Epoch 247/300
# 6/6 [==============================] - 3s 509ms/step - loss: 0.0762 - accuracy: 0.9583 - val_loss: 0.4847 - val_accuracy: 0.9474
# Epoch 248/300
# 6/6 [==============================] - 3s 508ms/step - loss: 1.3699e-04 - accuracy: 1.0000 - val_loss: 0.4201 - val_accuracy: 0.9605
# Epoch 249/300
# 6/6 [==============================] - 3s 533ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9737
# Epoch 250/300
# 6/6 [==============================] - 3s 522ms/step - loss: 6.3868e-04 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9737
# Epoch 251/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.0818 - val_accuracy: 0.9737
# Epoch 252/300
# 6/6 [==============================] - 3s 502ms/step - loss: 2.0606e-04 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9737
# Epoch 253/300
# 6/6 [==============================] - 3s 506ms/step - loss: 3.3982e-05 - accuracy: 1.0000 - val_loss: 0.2137 - val_accuracy: 0.9737
# Epoch 254/300
# 6/6 [==============================] - 3s 506ms/step - loss: 3.0520e-04 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9868
# Epoch 255/300
# 6/6 [==============================] - 3s 519ms/step - loss: 9.2777e-06 - accuracy: 1.0000 - val_loss: 0.0840 - val_accuracy: 0.9868
# Epoch 256/300
# 6/6 [==============================] - 3s 512ms/step - loss: 1.7272e-04 - accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9605
# Epoch 257/300
# 6/6 [==============================] - 3s 513ms/step - loss: 2.8783e-04 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9868
# Epoch 258/300
# 6/6 [==============================] - 3s 513ms/step - loss: 3.2974e-05 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9737
# Epoch 259/300
# 6/6 [==============================] - 3s 506ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.4709 - val_accuracy: 0.9342
# Epoch 260/300
# 6/6 [==============================] - 3s 496ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.3168 - val_accuracy: 0.9605
# Epoch 261/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3758 - val_accuracy: 0.9474
# Epoch 262/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2885 - val_accuracy: 0.9605
# Epoch 263/300
# 6/6 [==============================] - 3s 509ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4558 - val_accuracy: 0.9737
# Epoch 264/300
# 6/6 [==============================] - 3s 516ms/step - loss: 1.8904 - accuracy: 0.8750 - val_loss: 0.5563 - val_accuracy: 0.9474
# Epoch 265/300
# 6/6 [==============================] - 3s 523ms/step - loss: 3.6326e-04 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9868
# Epoch 266/300
# 6/6 [==============================] - 3s 509ms/step - loss: 3.9113e-05 - accuracy: 1.0000 - val_loss: 0.4341 - val_accuracy: 0.9605
# Epoch 267/300
# 6/6 [==============================] - 3s 503ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.9474
# Epoch 268/300
# 6/6 [==============================] - 3s 504ms/step - loss: 1.9620e-04 - accuracy: 1.0000 - val_loss: 0.5678 - val_accuracy: 0.9474
# Epoch 269/300
# 6/6 [==============================] - 3s 498ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9868
# Epoch 270/300
# 6/6 [==============================] - 3s 504ms/step - loss: 3.9562e-06 - accuracy: 1.0000 - val_loss: 0.5418 - val_accuracy: 0.9605
# Epoch 271/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6561 - val_accuracy: 0.9605
# Epoch 272/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.6190 - accuracy: 0.8750 - val_loss: 0.2769 - val_accuracy: 0.9737
# Epoch 273/300
# 6/6 [==============================] - 3s 517ms/step - loss: 3.9129e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9868
# Epoch 274/300
# 6/6 [==============================] - 3s 510ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3180 - val_accuracy: 0.9737
# Epoch 275/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2781 - val_accuracy: 0.9868
# Epoch 276/300
# 6/6 [==============================] - 3s 505ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.2972 - val_accuracy: 0.9737
# Epoch 277/300
# 6/6 [==============================] - 3s 497ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4553 - val_accuracy: 0.9737
# Epoch 278/300
# 6/6 [==============================] - 3s 492ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3556 - val_accuracy: 0.9737
# Epoch 279/300
# 6/6 [==============================] - 3s 511ms/step - loss: 3.9022e-05 - accuracy: 1.0000 - val_loss: 0.3584 - val_accuracy: 0.9737
# Epoch 280/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3777 - val_accuracy: 0.9737
# Epoch 281/300
# 6/6 [==============================] - 3s 502ms/step - loss: 3.4887e-04 - accuracy: 1.0000 - val_loss: 0.3596 - val_accuracy: 0.9737
# Epoch 282/300
# 6/6 [==============================] - 3s 507ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9605
# Epoch 283/300
# 6/6 [==============================] - 3s 513ms/step - loss: 0.8386 - accuracy: 0.9583 - val_loss: 0.3236 - val_accuracy: 0.9737
# Epoch 284/300
# 6/6 [==============================] - 3s 499ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5680 - val_accuracy: 0.9605
# Epoch 285/300
# 6/6 [==============================] - 3s 494ms/step - loss: 1.7598e-04 - accuracy: 1.0000 - val_loss: 0.2766 - val_accuracy: 0.9868
# Epoch 286/300
# 6/6 [==============================] - 3s 490ms/step - loss: 0.3732 - accuracy: 0.9583 - val_loss: 0.3247 - val_accuracy: 0.9605
# Epoch 287/300
# 6/6 [==============================] - 3s 485ms/step - loss: 0.7289 - accuracy: 0.9167 - val_loss: 0.6466 - val_accuracy: 0.9211
# Epoch 288/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0717 - accuracy: 0.9583 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 289/300
# 6/6 [==============================] - 3s 504ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.3025 - val_accuracy: 0.9474
# Epoch 290/300
# 6/6 [==============================] - 3s 504ms/step - loss: 8.5021e-04 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9605
# Epoch 291/300
# 6/6 [==============================] - 3s 505ms/step - loss: 1.4911e-05 - accuracy: 1.0000 - val_loss: 0.3228 - val_accuracy: 0.9474
# Epoch 292/300
# 6/6 [==============================] - 3s 499ms/step - loss: 2.5105e-04 - accuracy: 1.0000 - val_loss: 0.3505 - val_accuracy: 0.9474
# Epoch 293/300
# 6/6 [==============================] - 3s 503ms/step - loss: 0.0523 - accuracy: 0.9583 - val_loss: 0.1675 - val_accuracy: 0.9868
# Epoch 294/300
# 6/6 [==============================] - 3s 495ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9868
# Epoch 295/300
# 6/6 [==============================] - 3s 501ms/step - loss: 5.6275e-04 - accuracy: 1.0000 - val_loss: 2.5590e-04 - val_accuracy: 1.0000
# Epoch 296/300
# 6/6 [==============================] - 3s 491ms/step - loss: 3.5558e-04 - accuracy: 1.0000 - val_loss: 0.3969 - val_accuracy: 0.9737
# Epoch 297/300
# 6/6 [==============================] - 3s 503ms/step - loss: 3.2815e-04 - accuracy: 1.0000 - val_loss: 0.4023 - val_accuracy: 0.9737
# Epoch 298/300
# 6/6 [==============================] - 3s 504ms/step - loss: 5.8250e-05 - accuracy: 1.0000 - val_loss: 0.4119 - val_accuracy: 0.9737
# Epoch 299/300
# 6/6 [==============================] - 3s 502ms/step - loss: 0.0677 - accuracy: 0.9583 - val_loss: 0.3845 - val_accuracy: 0.9605
# Epoch 300/300
# 6/6 [==============================] - 3s 515ms/step - loss: 0.2664 - accuracy: 0.9583 - val_loss: 0.4219 - val_accuracy: 0.9605

# %% [markdown]
# ## Eğitim sonucunu görselleşitiriyoruz.

# %%
N = 300
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), hist.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), hist.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), hist.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), hist.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot.png")

# %% [markdown]
# ## Modeli kaydediyoruz.

# %%
model.save("/content/drive/My Drive/mama-kabı/binary_100epoch_saved.h5")

# %%
from tensorflow.keras.models import load_model
model= load_model("/content/drive/My Drive/mama-kabı/binary_100epoch_saved.h5")

# %% [markdown]
# ## Modeli test ediyoruz.

# %%
from keras.preprocessing.image import ImageDataGenerator
img_width=256
img_height=img_width
test_data_dir = '/content/drive/My Drive/mama-kabı/test'
test_datagen = ImageDataGenerator(rescale=1./255)


test_generator = test_datagen.flow_from_directory(
        test_data_dir,  # this is the target directory
        target_size=(img_width, img_height),  
        batch_size=1,
        class_mode='binary',shuffle=False) 
test_generator.reset()
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
scores = model.evaluate(test_generator,steps=STEP_SIZE_TEST) # testing images
print("Accuracy = ", scores[1])
# Out:
# Found 83 images belonging to 2 classes.
# 83/83 [==============================] - 2s 25ms/step - loss: 0.9474 - accuracy: 0.9398
# Accuracy =  0.9397590160369873

# %%
import cv2
import glob
import numpy as np
import os,fnmatch
import collections
imagesize=256
leng=len(glob.glob('/content/drive/My Drive/mama-kabı/test/*/*.JPG'))
xtest = np.ndarray(shape=(leng , imagesize, imagesize,3), dtype=np.uint8)
classes=np.ndarray(leng,dtype=np.uint8)

l=['dolu','boş']
index=0
for i in l:
  classDirectoryName='/content/drive/My Drive/mama-kabı/test/'+ i+'/*.JPG'
  for image in glob.glob(classDirectoryName):

    img =cv2.imread(image)
    img=img/255
    xtest[index]=cv2.resize(img, (imagesize, imagesize))

    if i=='boş':
      classes[index]=1
    else:
      classes[index]=0
   
    index +=1
print("0:dolu 1:boş  ---> ",collections.Counter(classes))
# Out:
# 0:dolu 1:boş  --->  Counter({1: 53, 0: 30})

# %% [markdown]
# ## Test sonuçlarını görselleştiriyoruz.

# %%
import os
import glob
import numpy as np
import cv2

g=glob.glob('/content/drive/My Drive/mama-kabı/test/dolu/*.JPG')
index=0
imagesize=256
xdeneme= np.ndarray(shape=(len(g) , imagesize, imagesize,3), dtype=np.uint8)


for i in g[0:len(g)]:
  img =cv2.imread(i)
  xdeneme[index]=img
  index+=1

result=model.predict(xdeneme)
result=["dolu" if i==1 else "boş" for i in result ]

fig, axis = plt.subplots(5, 4, figsize=(20,20))
fig.subplots_adjust(hspace=0.2, wspace=0.2)

for i, ax in enumerate(axis.flat):   
    ax.set_xticks([])
    ax.set_yticks([])
k=0
for i in range(0,4):
  for j in range(0,5):
      axis[j, i].imshow(xdeneme[k], cmap=plt.get_cmap("gray"))
      axis[j, i].set_xlabel(result[k], fontsize=15)
      k+=1

# %%
import os
import glob
import numpy as np
import cv2

g=glob.glob('/content/drive/My Drive/mama-kabı/test/boş/*.JPG')
index=0
imagesize=256
xdeneme= np.ndarray(shape=(len(g) , imagesize, imagesize,3), dtype=np.uint8)


for i in g[0:len(g)]:
  img =cv2.imread(i)
  xdeneme[index]=img
  index+=1

result=model.predict(xdeneme)
result=["dolu" if i==1 else "boş" for i in result ]

fig, axis = plt.subplots(5, 4, figsize=(20,20))
fig.subplots_adjust(hspace=0.2, wspace=0.2)

for i, ax in enumerate(axis.flat):   
    ax.set_xticks([])
    ax.set_yticks([])
k=0
for i in range(0,4):
  for j in range(0,5):
      axis[j, i].imshow(xdeneme[k], cmap=plt.get_cmap("gray"))
      axis[j, i].set_xlabel(result[k], fontsize=15)
      k+=1
